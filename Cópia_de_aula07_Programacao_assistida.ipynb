# %% [markdown]
# <a href="https://colab.research.google.com/github/alanbatistaudf/Engenharia_de_Prompt_Aplicacoes_Ai/blob/main/C%C3%B3pia_de_aula07_Programacao_assistida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numeros = [1, 3, 6, 7, 8]
soma = 0
for num in numeros:
  soma += num
  print (soma)
# Out:
# 1
# 4
# 10
# 17
# 25
